# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\nanda\OneDrive\Documents\Desktop\open cv
# ['Basics using skimages.ipynb', 'bilateral image.ipynb', 'Blending images.ipynb', 'Brightness and contrast.ipynb', 'color_conversion_notebook.ipynb', 'color_spaces_notebook.ipynb', 'DIlation.ipynb', 'Erosion.ipynb', 'Experiment 1 (shapes).ipynb', 'GaussianBlur.ipynb', 'img thresholding.ipynb', 'mani2.jpg', 'median filter.ipynb', 'MNIST_CNN_Student_Workbook.ipynb', 'opencv_basics_notebook.ipynb', 'WhatsApp Image 2026-06-22 at 9.25.29 PM.jpeg', 'WhatsApp Image 2026-06-22 at 9.25.32 PM.jpeg', 'WhatsApp Image 2026-06-22 at 9.25.34 PM.jpeg']
