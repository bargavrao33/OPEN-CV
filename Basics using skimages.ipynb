# %%
# !pip install scikit-image
# Out:
# ...
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------- ----------------------------- 3.1/12.0 MB 17.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.7/12.0 MB 20.9 MB/s eta 0:00:01
#    ---------------------------------------  11.8/12.0 MB 21.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 18.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 15.3 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/5 [tifffile]
#    ---------------------------------------- 0/5 [tifffile]
#    ---------------------------------------- 0/5 [tifffile]
#    ---------------------------------------- 0/5 [tifffile]
#    ---------------------------------------- 0/5 [tifffile]
#    ---------------------------------------- 0/5 [tifffile]
#    ---------------------------------------- 0/5 [tifffile]
# ...

# %%
from skimage import io 
img = io.imread('mani2.jpg') 
io.imshow(img)
# Out:
# C:\Users\nanda\AppData\Local\Temp\ipykernel_15268\324622164.py:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img)

# %%
from skimage import io

# Read image
img = io.imread("mani2.jpg")

# Print image dimensions
print("Image Shape:", img.shape)
# Out:
# Image Shape: (2160, 3840, 3)

# %%
from skimage import io

img = io.imread("mani2.jpg")

height = img.shape[0]
width = img.shape[1]
channels = img.shape[2]

print("Height =", height)
print("Width =", width)
print("Channels =", channels)
# Out:
# Height = 2160
# Width = 3840
# Channels = 3

# %%
from skimage import io

img = io.imread("mani2.jpg")

print("Data Type:", img.dtype)
# Out:
# Data Type: uint8

# %%
from skimage import io

img = io.imread("mani2.jpg")

# Pixel at row 100, column 100
print(img[100,100])
# Out:
# [137 172 210]

# %%
from skimage import io

img = io.imread("mani2.jpg")

print("Total Pixels =", img.size)
# Out:
# Total Pixels = 24883200

# %%
from skimage import io
import matplotlib.pyplot as plt

img = io.imread("mani2.jpg")

plt.imshow(img)
plt.title("Original Image")
plt.show()

# %%
from skimage import io

img = io.imread("mani2.jpg")

# Crop region
crop = img[100:400, 100:400]

io.imshow(crop)
io.show()
# Out:
# C:\Users\nanda\AppData\Local\Temp\ipykernel_15268\2623073980.py:8: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(crop)
# C:\Users\nanda\AppData\Local\Temp\ipykernel_15268\2623073980.py:9: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io

img = io.imread("mani2.jpg")

red = img[:,:,0]

io.imshow(red)
io.show()
# Out:
# C:\Users\nanda\AppData\Local\Temp\ipykernel_15268\3911525008.py:7: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(red)
# C:\Users\nanda\AppData\Local\Temp\ipykernel_15268\3911525008.py:8: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io

img = io.imread("mani2.jpg")

green = img[:,:,1]

io.imshow(green)
io.show()
# Out:
# C:\Users\nanda\AppData\Local\Temp\ipykernel_15268\602847416.py:7: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(green)
# C:\Users\nanda\AppData\Local\Temp\ipykernel_15268\602847416.py:8: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
